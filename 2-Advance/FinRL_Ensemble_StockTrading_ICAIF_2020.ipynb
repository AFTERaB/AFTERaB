# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# ## install finrl library
# !pip install wrds
# !pip install swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wrds
#   Downloading wrds-3.1.5-py3-none-any.whl (12 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from wrds) (1.7.3)
# Requirement already satisfied: sqlalchemy<2 in /usr/local/lib/python3.8/dist-packages (from wrds) (1.4.46)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from wrds) (1.3.5)
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 13.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from wrds) (1.22.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.8/dist-packages (from sqlalchemy<2->wrds) (2.0.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->wrds) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->wrds) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->wrds) (1.15.0)
# Installing collected packages: psycopg2-binary, wrds
# Successfully installed psycopg2-binary-2.9.5 wrds-3.1.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting swig
#   Downloading swig-4.1.1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 15.4 MB/s eta 0:00:00
# Installing collected packages: swig
# Successfully installed swig-4.1.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to /tmp/pip-req-build-eowpglab
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git /tmp/pip-req-build-eowpglab
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit 3d7acdcd8b1217321852758d5b91dacf2f9e64b1
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /tmp/pip-install-f7cfbcia/elegantrl_4a40916cf31045199788915cd66192b9
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /tmp/pip-install-f7cfbcia/elegantrl_4a40916cf31045199788915cd66192b9
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 68bf0ea4ef3fb461026ece8897deabb92aeead32
#   Preparing metadata (setup.py) ... done
# Collecting pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2
#   Cloning https://github.com/quantopian/pyfolio.git to /tmp/pip-install-f7cfbcia/pyfolio_e0d963e2e342496f9f622d039d7e1616
#   Running command git clone --filter=blob:none --quiet https://github.com/quantopian/pyfolio.git /tmp/pip-install-f7cfbcia/pyfolio_e0d963e2e342496f9f622d039d7e1616
#   Resolved https://github.com/quantopian/pyfolio.git to commit 4b901f6d73aa02ceb6d04b7d83502e5c6f2e81aa
#   Preparing metadata (setup.py) ... done
# Collecting ray[default,tune]>=2.0.0
#   Downloading ray-2.3.0-cp38-cp38-manylinux2014_x86_64.whl (58.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.6/58.6 MB 13.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from finrl==0.3.5) (1.22.4)
# Collecting stockstats>=0.4.0
#   Downloading stockstats-0.5.2-py2.py3-none-any.whl (20 kB)
# Collecting gputil
#   Downloading GPUtil-1.4.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting lz4
#   Downloading lz4-4.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 71.1 MB/s eta 0:00:00
# Collecting importlib-metadata==4.13.0
#   Downloading importlib_metadata-4.13.0-py3-none-any.whl (23 kB)
# Collecting tensorboardX
#   Downloading tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 KB 15.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.8/dist-packages (from finrl==0.3.5) (1.3.5)
# Requirement already satisfied: scikit-learn>=0.21.0 in /usr/local/lib/python3.8/dist-packages (from finrl==0.3.5) (1.0.2)
# Collecting stable-baselines3<2.0.0,>=1.6.2
#   Downloading stable_baselines3-1.7.0-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.8/171.8 KB 20.4 MB/s eta 0:00:00
# Collecting ccxt>=1.66.32
#   Downloading ccxt-2.8.54-py2.py3-none-any.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 81.8 MB/s eta 0:00:00
# Collecting yfinance
#   Downloading yfinance-0.2.12-py2.py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 KB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: gym>=0.17 in /usr/local/lib/python3.8/dist-packages (from finrl==0.3.5) (0.25.2)
# Collecting alpaca_trade_api>=2.1.0
#   Downloading alpaca_trade_api-2.3.0-py3-none-any.whl (33 kB)
# Collecting jqdatasdk
#   Downloading jqdatasdk-1.8.11-py3-none-any.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 KB 20.5 MB/s eta 0:00:00
# Collecting exchange_calendars==3.6.3
#   Downloading exchange_calendars-3.6.3.tar.gz (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.8/152.8 KB 18.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from finrl==0.3.5) (3.5.3)
# Collecting pyluach
#   Downloading pyluach-2.1.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.8/dist-packages (from exchange_calendars==3.6.3->finrl==0.3.5) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from exchange_calendars==3.6.3->finrl==0.3.5) (2022.7.1)
# Requirement already satisfied: toolz in /usr/local/lib/python3.8/dist-packages (from exchange_calendars==3.6.3->finrl==0.3.5) (0.12.0)
# Requirement already satisfied: korean_lunar_calendar in /usr/local/lib/python3.8/dist-packages (from exchange_calendars==3.6.3->finrl==0.3.5) (0.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata==4.13.0->finrl==0.3.5) (3.14.0)
# Collecting aiohttp==3.8.1
#   Downloading aiohttp-3.8.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 71.8 MB/s eta 0:00:00
# Collecting websockets<11,>=9.0
#   Downloading websockets-10.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 KB 13.7 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML==6.0 in /usr/local/lib/python3.8/dist-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (6.0)
# Collecting msgpack==1.0.3
#   Downloading msgpack-1.0.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (322 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.4/322.4 KB 29.2 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>2 in /usr/local/lib/python3.8/dist-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (2.25.1)
# Collecting deprecation==2.1.0
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting websocket-client<2,>=0.56.0
#   Downloading websocket_client-1.5.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 KB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<2,>1.24 in /usr/local/lib/python3.8/dist-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (1.24.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp==3.8.1->alpaca_trade_api>=2.1.0->finrl==0.3.5) (1.8.2)
# Collecting charset-normalizer<3.0,>=2.0
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp==3.8.1->alpaca_trade_api>=2.1.0->finrl==0.3.5) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp==3.8.1->alpaca_trade_api>=2.1.0->finrl==0.3.5) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp==3.8.1->alpaca_trade_api>=2.1.0->finrl==0.3.5) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp==3.8.1->alpaca_trade_api>=2.1.0->finrl==0.3.5) (22.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp==3.8.1->alpaca_trade_api>=2.1.0->finrl==0.3.5) (6.0.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from deprecation==2.1.0->alpaca_trade_api>=2.1.0->finrl==0.3.5) (23.0)
# Collecting setuptools>=60.9.0
#   Downloading setuptools-67.4.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 59.4 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2018.1.18 in /usr/local/lib/python3.8/dist-packages (from ccxt>=1.66.32->finrl==0.3.5) (2022.12.7)
# Collecting aiodns>=1.1.1
#   Downloading aiodns-3.0.0-py3-none-any.whl (5.0 kB)
# Collecting cryptography>=2.6.1
#   Downloading cryptography-39.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 63.0 MB/s eta 0:00:00
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.8/dist-packages (from gym>=0.17->finrl==0.3.5) (0.0.8)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from gym>=0.17->finrl==0.3.5) (2.2.1)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.8/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (3.19.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (3.9.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.8/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (7.1.2)
# Requirement already satisfied: grpcio>=1.32.0 in /usr/local/lib/python3.8/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (1.51.3)
# Collecting virtualenv>=20.0.24
#   Downloading virtualenv-20.19.0-py3-none-any.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 63.7 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.8/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (4.3.3)
# Collecting gpustat>=1.0.0
#   Downloading gpustat-1.0.0.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.5/90.5 KB 11.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting opencensus
#   Downloading opencensus-0.11.1-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 KB 16.0 MB/s eta 0:00:00
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.8/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (0.16.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.8/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (1.10.5)
# Collecting py-spy>=0.2.0
#   Downloading py_spy-0.3.14-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 78.0 MB/s eta 0:00:00
# Collecting aiohttp-cors
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Collecting colorful
#   Downloading colorful-0.5.5-py2.py3-none-any.whl (201 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 KB 23.7 MB/s eta 0:00:00
# Requirement already satisfied: smart-open in /usr/local/lib/python3.8/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (6.3.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.8/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (0.8.10)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.21.0->finrl==0.3.5) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.21.0->finrl==0.3.5) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.21.0->finrl==0.3.5) (1.2.0)
# Collecting gym>=0.17
#   Downloading gym-0.21.0.tar.gz (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 65.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.8/dist-packages (from stable-baselines3<2.0.0,>=1.6.2->finrl==0.3.5) (1.13.1+cu116)
# Collecting thriftpy2>=0.3.9
#   Downloading thriftpy2-0.4.16.tar.gz (643 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 643.4/643.4 KB 51.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: SQLAlchemy>=1.2.8 in /usr/local/lib/python3.8/dist-packages (from jqdatasdk->finrl==0.3.5) (1.4.46)
# Collecting pymysql>=0.7.6
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 KB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from jqdatasdk->finrl==0.3.5) (1.15.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->finrl==0.3.5) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->finrl==0.3.5) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->finrl==0.3.5) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->finrl==0.3.5) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->finrl==0.3.5) (0.11.0)
# Requirement already satisfied: ipython>=3.2.3 in /usr/local/lib/python3.8/dist-packages (from pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (7.9.0)
# Requirement already satisfied: seaborn>=0.7.1 in /usr/local/lib/python3.8/dist-packages (from pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.11.2)
# Collecting empyrical>=0.5.0
#   Downloading empyrical-0.5.5.tar.gz (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 KB 6.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting frozendict>=2.3.4
#   Downloading frozendict-2.3.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.2/111.2 KB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.8/dist-packages (from yfinance->finrl==0.3.5) (0.0.11)
# Collecting requests<3,>2
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 9.1 MB/s eta 0:00:00
# Collecting beautifulsoup4>=4.11.1
#   Downloading beautifulsoup4-4.11.2-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 KB 17.5 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.8/dist-packages (from yfinance->finrl==0.3.5) (4.9.2)
# Collecting html5lib>=1.1
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 KB 14.4 MB/s eta 0:00:00
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.8/dist-packages (from yfinance->finrl==0.3.5) (1.4.4)
# Collecting pycares>=4.0.0
#   Downloading pycares-4.3.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.0/289.0 KB 32.2 MB/s eta 0:00:00
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.4-py3-none-any.whl (37 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.8/dist-packages (from cryptography>=2.6.1->ccxt>=1.66.32->finrl==0.3.5) (1.15.1)
# Requirement already satisfied: pandas-datareader>=0.2 in /usr/local/lib/python3.8/dist-packages (from empyrical>=0.5.0->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.9.0)
# Collecting nvidia-ml-py<=11.495.46,>=11.450.129
#   Downloading nvidia_ml_py-11.495.46-py3-none-any.whl (25 kB)
# Collecting psutil>=5.6.0
#   Downloading psutil-5.9.4-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.2/280.2 KB 31.4 MB/s eta 0:00:00
# Collecting blessed>=1.17.1
#   Downloading blessed-1.20.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 KB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from html5lib>=1.1->yfinance->finrl==0.3.5) (0.5.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (2.6.1)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (2.0.10)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (5.7.1)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 74.5 MB/s eta 0:00:00
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (4.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>2->alpaca_trade_api>=2.1.0->finrl==0.3.5) (2.10)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.8/dist-packages (from SQLAlchemy>=1.2.8->jqdatasdk->finrl==0.3.5) (2.0.2)
# Collecting ply<4.0,>=3.4
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 KB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.11->stable-baselines3<2.0.0,>=1.6.2->finrl==0.3.5) (4.5.0)
# Requirement already satisfied: platformdirs<4,>=2.4 in /usr/local/lib/python3.8/dist-packages (from virtualenv>=20.0.24->ray[default,tune]>=2.0.0->finrl==0.3.5) (3.0.0)
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 KB 44.8 MB/s eta 0:00:00
# Collecting gym[box2d]
#   Downloading gym-0.26.2.tar.gz (721 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.7/721.7 KB 58.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Downloading gym-0.26.1.tar.gz (719 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.9/719.9 KB 50.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Downloading gym-0.26.0.tar.gz (710 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 710.3/710.3 KB 39.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Downloading gym-0.25.1.tar.gz (732 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 732.2/732.2 KB 13.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Downloading gym-0.25.0.tar.gz (720 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 720.4/720.4 KB 53.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Downloading gym-0.24.1.tar.gz (696 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 696.4/696.4 KB 55.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Downloading gym-0.24.0.tar.gz (694 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 694.4/694.4 KB 47.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Downloading gym-0.23.1.tar.gz (626 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 626.2/626.2 KB 40.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Downloading gym-0.23.0.tar.gz (624 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.4/624.4 KB 49.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Downloading gym-0.22.0.tar.gz (631 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 KB 38.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting box2d-py==2.3.5
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 KB 40.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pyglet>=1.4.0
#   Downloading pyglet-2.0.4-py3-none-any.whl (831 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.0/831.0 KB 57.2 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema->ray[default,tune]>=2.0.0->finrl==0.3.5) (5.12.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema->ray[default,tune]>=2.0.0->finrl==0.3.5) (0.19.3)
# Collecting opencensus-context>=0.1.3
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (2.11.0)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.8/dist-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default,tune]>=2.0.0->finrl==0.3.5) (0.2.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt>=1.66.32->finrl==0.3.5) (2.21)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.8/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (1.58.0)
# Requirement already satisfied: google-auth<3.0dev,>=2.14.1 in /usr/local/lib/python3.8/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (2.16.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.7.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (0.2.8)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (0.4.8)
# Building wheels for collected packages: finrl, exchange_calendars, gym, elegantrl, gputil, pyfolio, empyrical, gpustat, thriftpy2, box2d-py
#   Building wheel for finrl (pyproject.toml) ... done
#   Created wheel for finrl: filename=finrl-0.3.5-py3-none-any.whl size=2774120 sha256=bc78adc69e78f917d5f6cf7ff5253b18f11e19a4591e93e9c4b6bf8b59a3e769
#   Stored in directory: /tmp/pip-ephem-wheel-cache-u3h9xjxr/wheels/40/83/3b/1fdae3cf52844e165828ceb467518b7a110a263cbd6a2282be
#   Building wheel for exchange_calendars (setup.py) ... done
#   Created wheel for exchange_calendars: filename=exchange_calendars-3.6.3-py3-none-any.whl size=182636 sha256=be6b0128828c163611b7304987ee8dde782a12f013961349615ca0b2be7fafb9
#   Stored in directory: /root/.cache/pip/wheels/b7/5a/70/69aa223926486d0dee4ff7949dba488e671db1bef9e14040e7
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.21.0-py3-none-any.whl size=1616819 sha256=45982c205f2dc5f376db236c90e502e9b026ce390e0927978b251153403f9f8e
#   Stored in directory: /root/.cache/pip/wheels/27/6d/b3/a3a6e10704795c9b9000f1ab2dc480dfe7bed42f5972806e73
#   Building wheel for elegantrl (setup.py) ... done
#   Created wheel for elegantrl: filename=elegantrl-0.3.6-py3-none-any.whl size=195057 sha256=17bdf3cc38050050a76d2fc51a1863bf5b73cd768b41e825be11d8c40ea4edcd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-u3h9xjxr/wheels/d6/fb/88/7d5e5490b35f78191267fee312ce81baac55c6b9d89151e72a
#   Building wheel for gputil (setup.py) ... done
#   Created wheel for gputil: filename=GPUtil-1.4.0-py3-none-any.whl size=7409 sha256=70c5d1eee7d2c07a01d71d5a9566e9907c19265c74e8fe82e175a6d1b9edfd5c
#   Stored in directory: /root/.cache/pip/wheels/ba/03/bb/7a97840eb54479b328672e15a536e49dc60da200fb21564d53
#   Building wheel for pyfolio (setup.py) ... done
#   Created wheel for pyfolio: filename=pyfolio-0.9.2+75.g4b901f6-py3-none-any.whl size=75774 sha256=a510608477d9942c1074dbe5d026dd0e06ea57edf166779ce2d180585710837c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-u3h9xjxr/wheels/7b/59/8b/3c276a18b58c04a1fd0e1351e979fb5396f93fbde5b5438df1
#   Building wheel for empyrical (setup.py) ... done
#   Created wheel for empyrical: filename=empyrical-0.5.5-py3-none-any.whl size=39778 sha256=8dde529ad680e4e6635e882e6858c8ddc2e79ad53bad29d9025fccbf8204f742
#   Stored in directory: /root/.cache/pip/wheels/0d/68/bb/926065fb744e7d7cb67334cb1a9c696722abc8303e5dc9a8d0
#   Building wheel for gpustat (setup.py) ... done
#   Created wheel for gpustat: filename=gpustat-1.0.0-py3-none-any.whl size=19887 sha256=7056ed502739d8313aa265116c44709b60194c3686693c0821ddfefa00c574d4
#   Stored in directory: /root/.cache/pip/wheels/1b/ed/14/0d513c962b25da841c42022cb5847c2ef835902c8563b8fb01
#   Building wheel for thriftpy2 (setup.py) ... done
#   Created wheel for thriftpy2: filename=thriftpy2-0.4.16-cp38-cp38-linux_x86_64.whl size=1244472 sha256=afdbb99251294eb15a40b5983036419f28a6f04210c152c5e4a365564664512f
#   Stored in directory: /root/.cache/pip/wheels/a2/62/fd/0862bb8a1775cdea40a14af28ae2b490c9c32555df3361f590
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp38-cp38-linux_x86_64.whl size=2836990 sha256=13cd2caaf75763ea05a6676e6b7ad82f9ba4c263c3b06b6181cd3015e9d4c654
#   Stored in directory: /root/.cache/pip/wheels/8b/95/16/1dc99ff9a3f316ff245fdb5c9086cd13c35dad630809909075
# Successfully built finrl exchange_calendars gym elegantrl gputil pyfolio empyrical gpustat thriftpy2 box2d-py
# Installing collected packages: pyglet, py-spy, ply, opencensus-context, nvidia-ml-py, msgpack, gputil, distlib, colorful, box2d-py, websockets, websocket-client, virtualenv, thriftpy2, tensorboardX, soupsieve, setuptools, pymysql, pyluach, psutil, lz4, jedi, importlib-metadata, html5lib, gym, frozendict, deprecation, charset-normalizer, blessed, requests, pycares, gpustat, cryptography, beautifulsoup4, aiohttp, yfinance, stockstats, stable-baselines3, ray, jqdatasdk, exchange_calendars, elegantrl, alpaca_trade_api, aiohttp-cors, aiodns, opencensus, empyrical, ccxt, pyfolio, finrl
#   Attempting uninstall: msgpack
#     Found existing installation: msgpack 1.0.4
#     Uninstalling msgpack-1.0.4:
#       Successfully uninstalled msgpack-1.0.4
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
#       Successfully uninstalled setuptools-57.4.0
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 6.0.0
#     Uninstalling importlib-metadata-6.0.0:
#       Successfully uninstalled importlib-metadata-6.0.0
#   Attempting uninstall: html5lib
#     Found existing installation: html5lib 1.0.1
#     Uninstalling html5lib-1.0.1:
#       Successfully uninstalled html5lib-1.0.1
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.0.1
#     Uninstalling charset-normalizer-3.0.1:
#       Successfully uninstalled charset-normalizer-3.0.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.8.4
#     Uninstalling aiohttp-3.8.4:
#       Successfully uninstalled aiohttp-3.8.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cvxpy 1.2.3 requires setuptools<=64.0.2, but you have setuptools 67.4.0 which is incompatible.
# Successfully installed aiodns-3.0.0 aiohttp-3.8.1 aiohttp-cors-0.7.0 alpaca_trade_api-2.3.0 beautifulsoup4-4.11.2 blessed-1.20.0 box2d-py-2.3.5 ccxt-2.8.54 charset-normalizer-2.1.1 colorful-0.5.5 cryptography-39.0.1 deprecation-2.1.0 distlib-0.3.6 elegantrl-0.3.6 empyrical-0.5.5 exchange_calendars-3.6.3 finrl-0.3.5 frozendict-2.3.5 gpustat-1.0.0 gputil-1.4.0 gym-0.21.0 html5lib-1.1 importlib-metadata-4.13.0 jedi-0.18.2 jqdatasdk-1.8.11 lz4-4.3.2 msgpack-1.0.3 nvidia-ml-py-11.495.46 opencensus-0.11.1 opencensus-context-0.1.3 ply-3.11 psutil-5.9.4 py-spy-0.3.14 pycares-4.3.0 pyfolio-0.9.2+75.g4b901f6 pyglet-2.0.4 pyluach-2.1.0 pymysql-1.0.2 ray-2.3.0 requests-2.28.2 setuptools-67.4.0 soupsieve-2.4 stable-baselines3-1.7.0 stockstats-0.5.2 tensorboardX-2.6 thriftpy2-0.4.16 virtualenv-20.19.0 websocket-client-1.5.1 websockets-10.4 yfinance-0.2.12

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
print(['DIA','DOG','QQQ','SPY','TLT','IWO','VUG','GME'])
# Out:
# ['DIA', 'DOG', 'QQQ', 'SPY', 'TLT', 'IWO', 'VUG', 'GME']

# %%
TRAIN_START_DATE = '2020-04-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2022-06-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = ['DIA','DOG','QQQ','SPY','TLT','IWO','VUG','GME']).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (4368, 8)

# %%
df.head()

# %%
df.tail()

# %%
df.shape

# %%
df.sort_values(['date','tic']).head()

# %%
len(df.tic.unique())

# %%
df.tic.value_counts()
# Out:
# DIA    546
# DOG    546
# GME    546
# IWO    546
# QQQ    546
# SPY    546
# TLT    546
# VUG    546
# Name: tic, dtype: int64

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
#  INDICATORS = ['macd_12',
#                'rsi_30',
#                'cci_30',
#                'dx_20']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)

# %%
processed.sample(5)

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 8, State Space: 81

# %%
env_kwargs = {
    "hmax":100, 
    "initial_amount": 1000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 6e-1,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 50,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.0005,
                    "batch_size": 400
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 400
                    }

timesteps_dict = {'a2c' : 10_000, 
                 'ppo' : 10_000, 
                 'ddpg' : 10_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  0.0
# ======Model training from:  2020-04-01 to  2021-01-04
# ======A2C Training========
# {'n_steps': 50, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_126_18
# day: 190, episode: 10
# begin_total_asset: 1000.00
# end_total_asset: 1089.09
# total_reward: 89.09
# total_cost: 65.15
# total_trades: 1120
# Sharpe: 0.495
# =================================
# day: 190, episode: 20
# begin_total_asset: 1000.00
# end_total_asset: 3255.76
# total_reward: 2255.76
# total_cost: 29.13
# total_trades: 1051
# Sharpe: 1.926
# =================================
# ---------------------------------------
# | time/                 |             |
# |    fps                | 439         |
# |    iterations         | 100         |
# |    time_elapsed       | 11          |
# |    total_timesteps    | 5000        |
# | train/                |             |
# |    entropy_loss       | -11.5       |
# |    explained_variance | -0.26       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | -1.49       |
# |    reward             | 0.014728014 |
# |    std                | 1.03        |
# |    value_loss         | 0.0208      |
# ---------------------------------------
# day: 190, episode: 30
# begin_total_asset: 1000.00
# end_total_asset: 2369.88
# total_reward: 1369.88
# total_cost: 16.97
# total_trades: 1099
# Sharpe: 1.615
# =================================
# day: 190, episode: 40
# begin_total_asset: 1000.00
# end_total_asset: 1846.04
# total_reward: 846.04
# total_cost: 30.51
# total_trades: 1023
# Sharpe: 1.366
# =================================
# day: 190, episode: 50
# begin_total_asset: 1000.00
# end_total_asset: 2983.02
# total_reward: 1983.02
# total_cost: 49.10
# total_trades: 965
# Sharpe: 1.938
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 420           |
# |    iterations         | 200           |
# |    time_elapsed       | 23            |
# |    total_timesteps    | 10000         |
# | train/                |               |
# |    entropy_loss       | -11.6         |
# |    explained_variance | -0.0291       |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 199           |
# |    policy_loss        | -0.983        |
# |    reward             | -0.0033225126 |
# |    std                | 1.04          |
# |    value_loss         | 0.0247        |
# -----------------------------------------
# ======A2C Validation from:  2021-01-04 to  2021-04-06
# A2C Sharpe Ratio:  0.0
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.0005, 'batch_size': 400}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_126_12
# day: 190, episode: 60
# begin_total_asset: 1000.00
# end_total_asset: 1007.54
# total_reward: 7.54
# total_cost: 137.56
# total_trades: 913
# Sharpe: 0.252
# =================================
# --------------------------------------
# | time/              |               |
# |    fps             | 387           |
# |    iterations      | 1             |
# |    time_elapsed    | 5             |
# |    total_timesteps | 2048          |
# | train/             |               |
# |    reward          | -0.0021618982 |
# --------------------------------------
# day: 190, episode: 70
# begin_total_asset: 1000.00
# end_total_asset: 759.15
# total_reward: -240.85
# total_cost: 122.22
# total_trades: 954
# Sharpe: -0.429
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 372           |
# |    iterations           | 2             |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.009523146   |
# |    clip_fraction        | 0.0802        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | -3.38         |
# |    learning_rate        | 0.0005        |
# |    loss                 | -0.111        |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.0156       |
# |    reward               | -0.0024227034 |
# |    std                  | 1             |
# |    value_loss           | 0.0264        |
# -------------------------------------------
# day: 190, episode: 80
# begin_total_asset: 1000.00
# end_total_asset: 890.44
# total_reward: -109.56
# total_cost: 127.82
# total_trades: 941
# Sharpe: 0.111
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 396          |
# |    iterations           | 3            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.009185607  |
# |    clip_fraction        | 0.0858       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11.4        |
# |    explained_variance   | -0.783       |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.125       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0121      |
# |    reward               | -0.011213457 |
# |    std                  | 1            |
# |    value_loss           | 0.00655      |
# ------------------------------------------
# day: 190, episode: 90
# begin_total_asset: 1000.00
# end_total_asset: 1149.97
# total_reward: 149.97
# total_cost: 98.75
# total_trades: 946
# Sharpe: 0.734
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 395           |
# |    iterations           | 4             |
# |    time_elapsed         | 20            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.0133609595  |
# |    clip_fraction        | 0.142         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | -0.74         |
# |    learning_rate        | 0.0005        |
# |    loss                 | -0.121        |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.0182       |
# |    reward               | -0.0023082276 |
# |    std                  | 1.01          |
# |    value_loss           | 0.00481       |
# -------------------------------------------
# day: 190, episode: 100
# begin_total_asset: 1000.00
# end_total_asset: 1058.78
# total_reward: 58.78
# total_cost: 100.72
# total_trades: 958
# Sharpe: 0.494
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 381         |
# |    iterations           | 5           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009105144 |
# |    clip_fraction        | 0.0935      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.4       |
# |    explained_variance   | -0.00532    |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.134      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.014      |
# |    reward               | 0.05108103  |
# |    std                  | 1.01        |
# |    value_loss           | 0.00855     |
# -----------------------------------------
# ======PPO Validation from:  2021-01-04 to  2021-04-06
# PPO Sharpe Ratio:  0.0
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 400}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_126_9
# day: 190, episode: 110
# begin_total_asset: 1000.00
# end_total_asset: 3476.20
# total_reward: 2476.20
# total_cost: 1.00
# total_trades: 190
# Sharpe: 1.904
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 4            |
# |    fps             | 28           |
# |    time_elapsed    | 26           |
# |    total_timesteps | 764          |
# | train/             |              |
# |    actor_loss      | -9.52        |
# |    critic_loss     | 0.509        |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 573          |
# |    reward          | -0.046494007 |
# -------------------------------------
# -------------------------------------
# | time/              |              |
# |    episodes        | 8            |
# |    fps             | 24           |
# |    time_elapsed    | 61           |
# |    total_timesteps | 1528         |
# | train/             |              |
# |    actor_loss      | -8.56        |
# |    critic_loss     | 0.173        |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 1337         |
# |    reward          | -0.046494007 |
# -------------------------------------
# -------------------------------------
# | time/              |              |
# |    episodes        | 12           |
# |    fps             | 23           |
# |    time_elapsed    | 96           |
# |    total_timesteps | 2292         |
# | train/             |              |
# |    actor_loss      | -7.92        |
# |    critic_loss     | 0.0807       |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 2101         |
# |    reward          | -0.046494007 |
# -------------------------------------
# day: 190, episode: 120
# begin_total_asset: 1000.00
# end_total_asset: 3476.20
# total_reward: 2476.20
# total_cost: 1.00
# total_trades: 190
# Sharpe: 1.904
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 16           |
# |    fps             | 23           |
# |    time_elapsed    | 131          |
# |    total_timesteps | 3056         |
# | train/             |              |
# |    actor_loss      | -7.38        |
# |    critic_loss     | 0.103        |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 2865         |
# |    reward          | -0.046494007 |
# -------------------------------------
# -------------------------------------
# | time/              |              |
# |    episodes        | 20           |
# |    fps             | 22           |
# |    time_elapsed    | 166          |
# |    total_timesteps | 3820         |
# | train/             |              |
# |    actor_loss      | -6.92        |
# |    critic_loss     | 0.134        |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 3629         |
# |    reward          | -0.046494007 |
# -------------------------------------
# day: 190, episode: 130
# begin_total_asset: 1000.00
# end_total_asset: 3476.20
# total_reward: 2476.20
# total_cost: 1.00
# total_trades: 190
# Sharpe: 1.904
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 24           |
# |    fps             | 22           |
# |    time_elapsed    | 202          |
# |    total_timesteps | 4584         |
# | train/             |              |
# |    actor_loss      | -6.55        |
# |    critic_loss     | 0.077        |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 4393         |
# |    reward          | -0.046494007 |
# -------------------------------------
# -------------------------------------
# | time/              |              |
# |    episodes        | 28           |
# |    fps             | 22           |
# |    time_elapsed    | 241          |
# |    total_timesteps | 5348         |
# | train/             |              |
# |    actor_loss      | -6.21        |
# |    critic_loss     | 0.0305       |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 5157         |
# |    reward          | -0.046494007 |
# -------------------------------------
# -------------------------------------
# | time/              |              |
# |    episodes        | 32           |
# |    fps             | 21           |
# |    time_elapsed    | 280          |
# |    total_timesteps | 6112         |
# | train/             |              |
# |    actor_loss      | -5.91        |
# |    critic_loss     | 0.0359       |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 5921         |
# |    reward          | -0.046494007 |
# -------------------------------------
# day: 190, episode: 140
# begin_total_asset: 1000.00
# end_total_asset: 3476.20
# total_reward: 2476.20
# total_cost: 1.00
# total_trades: 190
# Sharpe: 1.904
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 36           |
# |    fps             | 21           |
# |    time_elapsed    | 316          |
# |    total_timesteps | 6876         |
# | train/             |              |
# |    actor_loss      | -5.6         |
# |    critic_loss     | 0.0375       |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 6685         |
# |    reward          | -0.046494007 |
# -------------------------------------
# -------------------------------------
# | time/              |              |
# |    episodes        | 40           |
# |    fps             | 21           |
# |    time_elapsed    | 350          |
# |    total_timesteps | 7640         |
# | train/             |              |
# |    actor_loss      | -5.29        |
# |    critic_loss     | 0.0151       |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 7449         |
# |    reward          | -0.046494007 |
# -------------------------------------
# day: 190, episode: 150
# begin_total_asset: 1000.00
# end_total_asset: 3476.20
# total_reward: 2476.20
# total_cost: 1.00
# total_trades: 190
# Sharpe: 1.904
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 44           |
# |    fps             | 21           |
# |    time_elapsed    | 385          |
# |    total_timesteps | 8404         |
# | train/             |              |
# |    actor_loss      | -5           |
# |    critic_loss     | 0.02         |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 8213         |
# |    reward          | -0.046494007 |
# -------------------------------------
# -------------------------------------
# | time/              |              |
# |    episodes        | 48           |
# |    fps             | 21           |
# |    time_elapsed    | 421          |
# |    total_timesteps | 9168         |
# | train/             |              |
# |    actor_loss      | -4.75        |
# |    critic_loss     | 0.0134       |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 8977         |
# |    reward          | -0.046494007 |
# -------------------------------------
# -------------------------------------
# | time/              |              |
# |    episodes        | 52           |
# |    fps             | 21           |
# |    time_elapsed    | 456          |
# |    total_timesteps | 9932         |
# | train/             |              |
# |    actor_loss      | -4.51        |
# |    critic_loss     | 0.00168      |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 9741         |
# |    reward          | -0.046494007 |
# -------------------------------------
# day: 190, episode: 160
# begin_total_asset: 1000.00
# end_total_asset: 3476.20
# total_reward: 2476.20
# total_cost: 1.00
# total_trades: 190
# Sharpe: 1.904
# =================================
# ======DDPG Validation from:  2021-01-04 to  2021-04-06
# ======Best Model Retraining from:  2020-04-01 to  2021-04-06
# ======Trading from:  2021-04-06 to  2021-07-06
# ============================================
# turbulence_threshold:  0.0
# ======Model training from:  2020-04-01 to  2021-04-06
# ======A2C Training========
# {'n_steps': 50, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_189_2
# day: 253, episode: 10
# begin_total_asset: 1000.00
# end_total_asset: 526.25
# total_reward: -473.75
# total_cost: 79.17
# total_trades: 1278
# Sharpe: -0.152
# =================================
# ---------------------------------------
# | time/                 |             |
# |    fps                | 393         |
# |    iterations         | 100         |
# |    time_elapsed       | 12          |
# |    total_timesteps    | 5000        |
# | train/                |             |
# |    entropy_loss       | -11.6       |
# |    explained_variance | 0.00602     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | -0.0654     |
# |    reward             | 0.007426427 |
# |    std                | 1.03        |
# |    value_loss         | 0.00219     |
# ---------------------------------------
# day: 253, episode: 20
# begin_total_asset: 1000.00
# end_total_asset: 3783.99
# total_reward: 2783.99
# total_cost: 370.36
# total_trades: 1245
# Sharpe: 1.983
# =================================
# day: 253, episode: 30
# begin_total_asset: 1000.00
# end_total_asset: 4550.94
# total_reward: 3550.94
# total_cost: 190.83
# total_trades: 1230
# Sharpe: 1.951
# =================================
# ------------------------------------------
# | time/                 |                |
# |    fps                | 417            |
# |    iterations         | 200            |
# |    time_elapsed       | 23             |
# |    total_timesteps    | 10000          |
# | train/                |                |
# |    entropy_loss       | -11.7          |
# |    explained_variance | 0.00453        |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 199            |
# |    policy_loss        | -1.37          |
# |    reward             | -0.00034586492 |
# |    std                | 1.05           |
# |    value_loss         | 0.0181         |
# ------------------------------------------
# ======A2C Validation from:  2021-04-06 to  2021-07-06
# A2C Sharpe Ratio:  0.0
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.0005, 'batch_size': 400}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_189_1
# -------------------------------------
# | time/              |              |
# |    fps             | 323          |
# |    iterations      | 1            |
# |    time_elapsed    | 6            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | 0.0031702972 |
# -------------------------------------
# day: 253, episode: 50
# begin_total_asset: 1000.00
# end_total_asset: 1306.61
# total_reward: 306.61
# total_cost: 161.40
# total_trades: 1286
# Sharpe: 0.814
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 377         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008879761 |
# |    clip_fraction        | 0.0976      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | -0.248      |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0155     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00988    |
# |    reward               | 0.010802047 |
# |    std                  | 1           |
# |    value_loss           | 0.167       |
# -----------------------------------------
# day: 253, episode: 60
# begin_total_asset: 1000.00
# end_total_asset: 2359.18
# total_reward: 1359.18
# total_cost: 303.99
# total_trades: 1241
# Sharpe: 1.536
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 398         |
# |    iterations           | 3           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.01142694  |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.4       |
# |    explained_variance   | -0.67       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.135      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0191     |
# |    reward               | 0.005828653 |
# |    std                  | 1.01        |
# |    value_loss           | 0.0162      |
# -----------------------------------------
# day: 253, episode: 70
# begin_total_asset: 1000.00
# end_total_asset: 507.30
# total_reward: -492.70
# total_cost: 34.53
# total_trades: 1139
# Sharpe: 1.563
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 371          |
# |    iterations           | 4            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.015937837  |
# |    clip_fraction        | 0.166        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11.4        |
# |    explained_variance   | 0.0632       |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.0778      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0122      |
# |    reward               | 0.0010614683 |
# |    std                  | 1            |
# |    value_loss           | 0.261        |
# ------------------------------------------
# day: 253, episode: 80
# begin_total_asset: 1000.00
# end_total_asset: 7762.15
# total_reward: 6762.15
# total_cost: 660.70
# total_trades: 1295
# Sharpe: 2.473
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 381         |
# |    iterations           | 5           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008827449 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.4       |
# |    explained_variance   | 0.16        |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0294     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0138     |
# |    reward               | -0.00277935 |
# |    std                  | 1           |
# |    value_loss           | 0.311       |
# -----------------------------------------
# ======PPO Validation from:  2021-04-06 to  2021-07-06
# PPO Sharpe Ratio:  0.0
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 400}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_189_1
# -------------------------------------
# | time/              |              |
# |    episodes        | 4            |
# |    fps             | 30           |
# |    time_elapsed    | 33           |
# |    total_timesteps | 1016         |
# | train/             |              |
# |    actor_loss      | -14.1        |
# |    critic_loss     | 0.225        |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 762          |
# |    reward          | 0.0054974374 |
# -------------------------------------
# -------------------------------------
# | time/              |              |
# |    episodes        | 8            |
# |    fps             | 25           |
# |    time_elapsed    | 80           |
# |    total_timesteps | 2032         |
# | train/             |              |
# |    actor_loss      | -13.2        |
# |    critic_loss     | 0.186        |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 1778         |
# |    reward          | 0.0054974374 |
# -------------------------------------
# day: 253, episode: 90
# begin_total_asset: 1000.00
# end_total_asset: 999.03
# total_reward: -0.97
# total_cost: 0.97
# total_trades: 1012
# Sharpe: 0.112
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 12           |
# |    fps             | 24           |
# |    time_elapsed    | 125          |
# |    total_timesteps | 3048         |
# | train/             |              |
# |    actor_loss      | -12.3        |
# |    critic_loss     | 0.225        |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 2794         |
# |    reward          | 0.0054974374 |
# -------------------------------------
# -------------------------------------
# | time/              |              |
# |    episodes        | 16           |
# |    fps             | 23           |
# |    time_elapsed    | 174          |
# |    total_timesteps | 4064         |
# | train/             |              |
# |    actor_loss      | -11.6        |
# |    critic_loss     | 0.0697       |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 3810         |
# |    reward          | 0.0054974374 |
# -------------------------------------
# day: 253, episode: 100
# begin_total_asset: 1000.00
# end_total_asset: 999.03
# total_reward: -0.97
# total_cost: 0.97
# total_trades: 1012
# Sharpe: 0.112
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 20           |
# |    fps             | 22           |
# |    time_elapsed    | 221          |
# |    total_timesteps | 5080         |
# | train/             |              |
# |    actor_loss      | -10.8        |
# |    critic_loss     | 0.0777       |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 4826         |
# |    reward          | 0.0054974374 |
# -------------------------------------
# -------------------------------------
# | time/              |              |
# |    episodes        | 24           |
# |    fps             | 22           |
# |    time_elapsed    | 268          |
# |    total_timesteps | 6096         |
# | train/             |              |
# |    actor_loss      | -10.1        |
# |    critic_loss     | 0.0417       |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 5842         |
# |    reward          | 0.0054974374 |
# -------------------------------------
# -------------------------------------
# | time/              |              |
# |    episodes        | 28           |
# |    fps             | 22           |
# |    time_elapsed    | 314          |
# |    total_timesteps | 7112         |
# | train/             |              |
# |    actor_loss      | -9.47        |
# |    critic_loss     | 0.0381       |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 6858         |
# |    reward          | 0.0054974374 |
# -------------------------------------
# day: 253, episode: 110
# begin_total_asset: 1000.00
# end_total_asset: 999.03
# total_reward: -0.97
# total_cost: 0.97
# total_trades: 1012
# Sharpe: 0.112
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 32           |
# |    fps             | 22           |
# |    time_elapsed    | 361          |
# |    total_timesteps | 8128         |
# | train/             |              |
# |    actor_loss      | -8.84        |
# |    critic_loss     | 0.0316       |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 7874         |
# |    reward          | 0.0054974374 |
# -------------------------------------
# -------------------------------------
# | time/              |              |
# |    episodes        | 36           |
# |    fps             | 22           |
# |    time_elapsed    | 411          |
# |    total_timesteps | 9144         |
# | train/             |              |
# |    actor_loss      | -8.25        |
# |    critic_loss     | 0.0274       |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 8890         |
# |    reward          | 0.0054974374 |
# -------------------------------------
# day: 253, episode: 120
# begin_total_asset: 1000.00
# end_total_asset: 999.03
# total_reward: -0.97
# total_cost: 0.97
# total_trades: 1012
# Sharpe: 0.112
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 40           |
# |    fps             | 22           |
# |    time_elapsed    | 459          |
# |    total_timesteps | 10160        |
# | train/             |              |
# |    actor_loss      | -7.67        |
# |    critic_loss     | 0.0166       |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 9906         |
# |    reward          | 0.0054974374 |
# -------------------------------------
# ======DDPG Validation from:  2021-04-06 to  2021-07-06
# ======Best Model Retraining from:  2020-04-01 to  2021-07-06
# ======Trading from:  2021-07-06 to  2021-10-04
# ============================================
# turbulence_threshold:  0.0
# ======Model training from:  2020-04-01 to  2021-07-06
# ======A2C Training========
# {'n_steps': 50, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_252_1
# day: 316, episode: 10
# begin_total_asset: 1000.00
# end_total_asset: 2064.04
# total_reward: 1064.04
# total_cost: 461.49
# total_trades: 1395
# Sharpe: 1.329
# =================================
# ---------------------------------------
# | time/                 |             |
# |    fps                | 388         |
# |    iterations         | 100         |
# |    time_elapsed       | 12          |
# |    total_timesteps    | 5000        |
# | train/                |             |
# |    entropy_loss       | -11.5       |
# |    explained_variance | -2.86       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | -0.673      |
# |    reward             | 0.012765422 |
# |    std                | 1.02        |
# |    value_loss         | 0.00532     |
# ---------------------------------------
# day: 316, episode: 20
# begin_total_asset: 1000.00
# end_total_asset: 1893.52
# total_reward: 893.52
# total_cost: 296.23
# total_trades: 1485
# Sharpe: 0.983
# =================================
# day: 316, episode: 30
# begin_total_asset: 1000.00
# end_total_asset: 26811.44
# total_reward: 25811.44
# total_cost: 1914.83
# total_trades: 1665
# Sharpe: 2.126
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 381           |
# |    iterations         | 200           |
# |    time_elapsed       | 26            |
# |    total_timesteps    | 10000         |
# | train/                |               |
# |    entropy_loss       | -11.6         |
# |    explained_variance | -0.226        |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 199           |
# |    policy_loss        | 2.4           |
# |    reward             | -0.0028794217 |
# |    std                | 1.04          |
# |    value_loss         | 0.0482        |
# -----------------------------------------
# ======A2C Validation from:  2021-07-06 to  2021-10-04
# A2C Sharpe Ratio:  0.0
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.0005, 'batch_size': 400}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_252_1
# -------------------------------------
# | time/              |              |
# |    fps             | 470          |
# |    iterations      | 1            |
# |    time_elapsed    | 4            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | 0.0017315054 |
# -------------------------------------
# day: 316, episode: 40
# begin_total_asset: 1000.00
# end_total_asset: 1874.84
# total_reward: 874.84
# total_cost: 363.09
# total_trades: 1573
# Sharpe: 1.026
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 373           |
# |    iterations           | 2             |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00890896    |
# |    clip_fraction        | 0.0668        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.3         |
# |    explained_variance   | -1.9          |
# |    learning_rate        | 0.0005        |
# |    loss                 | -0.0777       |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.0136       |
# |    reward               | -0.0024613175 |
# |    std                  | 0.998         |
# |    value_loss           | 0.068         |
# -------------------------------------------
# day: 316, episode: 50
# begin_total_asset: 1000.00
# end_total_asset: 1669.02
# total_reward: 669.02
# total_cost: 252.22
# total_trades: 1544
# Sharpe: 0.966
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 385          |
# |    iterations           | 3            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.009096003  |
# |    clip_fraction        | 0.0802       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11.3        |
# |    explained_variance   | -0.144       |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.114       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0103      |
# |    reward               | -0.012070705 |
# |    std                  | 1            |
# |    value_loss           | 0.0422       |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 387           |
# |    iterations           | 4             |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.01009654    |
# |    clip_fraction        | 0.11          |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0.304         |
# |    learning_rate        | 0.0005        |
# |    loss                 | -0.103        |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.0148       |
# |    reward               | -0.0007111568 |
# |    std                  | 0.999         |
# |    value_loss           | 0.0363        |
# -------------------------------------------
# day: 316, episode: 60
# begin_total_asset: 1000.00
# end_total_asset: 1807.18
# total_reward: 807.18
# total_cost: 315.73
# total_trades: 1620
# Sharpe: 1.054
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 364          |
# |    iterations           | 5            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0109461    |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11.4        |
# |    explained_variance   | 0.303        |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.108       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0121      |
# |    reward               | 0.0051205535 |
# |    std                  | 1            |
# |    value_loss           | 0.0345       |
# ------------------------------------------
# ======PPO Validation from:  2021-07-06 to  2021-10-04
# PPO Sharpe Ratio:  0.0
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 400}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_252_1
# -------------------------------------
# | time/              |              |
# |    episodes        | 4            |
# |    fps             | 30           |
# |    time_elapsed    | 40           |
# |    total_timesteps | 1268         |
# | train/             |              |
# |    actor_loss      | 4.05         |
# |    critic_loss     | 0.308        |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 951          |
# |    reward          | -0.007556259 |
# -------------------------------------
# day: 316, episode: 70
# begin_total_asset: 1000.00
# end_total_asset: 3448.76
# total_reward: 2448.76
# total_cost: 1.00
# total_trades: 948
# Sharpe: 1.394
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 8            |
# |    fps             | 24           |
# |    time_elapsed    | 103          |
# |    total_timesteps | 2536         |
# | train/             |              |
# |    actor_loss      | 3.46         |
# |    critic_loss     | 0.0878       |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 2219         |
# |    reward          | -0.007556259 |
# -------------------------------------
# -------------------------------------
# | time/              |              |
# |    episodes        | 12           |
# |    fps             | 23           |
# |    time_elapsed    | 160          |
# |    total_timesteps | 3804         |
# | train/             |              |
# |    actor_loss      | 3.16         |
# |    critic_loss     | 0.124        |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 3487         |
# |    reward          | -0.007556259 |
# -------------------------------------
# day: 316, episode: 80
# begin_total_asset: 1000.00
# end_total_asset: 3448.76
# total_reward: 2448.76
# total_cost: 1.00
# total_trades: 948
# Sharpe: 1.394
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 16           |
# |    fps             | 23           |
# |    time_elapsed    | 218          |
# |    total_timesteps | 5072         |
# | train/             |              |
# |    actor_loss      | 3.29         |
# |    critic_loss     | 0.0215       |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 4755         |
# |    reward          | -0.007556259 |
# -------------------------------------
# -------------------------------------
# | time/              |              |
# |    episodes        | 20           |
# |    fps             | 22           |
# |    time_elapsed    | 276          |
# |    total_timesteps | 6340         |
# | train/             |              |
# |    actor_loss      | 2.97         |
# |    critic_loss     | 0.05         |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 6023         |
# |    reward          | -0.007556259 |
# -------------------------------------
# -------------------------------------
# | time/              |              |
# |    episodes        | 24           |
# |    fps             | 22           |
# |    time_elapsed    | 336          |
# |    total_timesteps | 7608         |
# | train/             |              |
# |    actor_loss      | 2.64         |
# |    critic_loss     | 0.0331       |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 7291         |
# |    reward          | -0.007556259 |
# -------------------------------------
# day: 316, episode: 90
# begin_total_asset: 1000.00
# end_total_asset: 3448.76
# total_reward: 2448.76
# total_cost: 1.00
# total_trades: 948
# Sharpe: 1.394
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 28           |
# |    fps             | 22           |
# |    time_elapsed    | 396          |
# |    total_timesteps | 8876         |
# | train/             |              |
# |    actor_loss      | 2.37         |
# |    critic_loss     | 0.0206       |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 8559         |
# |    reward          | -0.007556259 |
# -------------------------------------
# -------------------------------------
# | time/              |              |
# |    episodes        | 32           |
# |    fps             | 22           |
# |    time_elapsed    | 454          |
# |    total_timesteps | 10144        |
# | train/             |              |
# |    actor_loss      | 2.11         |
# |    critic_loss     | 0.012        |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 9827         |
# |    reward          | -0.007556259 |
# -------------------------------------
# ======DDPG Validation from:  2021-07-06 to  2021-10-04
# ======Best Model Retraining from:  2020-04-01 to  2021-10-04
# ======Trading from:  2021-10-04 to  2022-01-03
# ============================================
# turbulence_threshold:  0.0
# ======Model training from:  2020-04-01 to  2021-10-04
# ======A2C Training========
# {'n_steps': 50, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_315_1
# day: 379, episode: 10
# begin_total_asset: 1000.00
# end_total_asset: 701.30
# total_reward: -298.70
# total_cost: 123.37
# total_trades: 1113
# Sharpe: -0.391
# =================================
# ------------------------------------------
# | time/                 |                |
# |    fps                | 363            |
# |    iterations         | 100            |
# |    time_elapsed       | 13             |
# |    total_timesteps    | 5000           |
# | train/                |                |
# |    entropy_loss       | -11.7          |
# |    explained_variance | -0.788         |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 99             |
# |    policy_loss        | -0.0545        |
# |    reward             | -0.00035613883 |
# |    std                | 1.04           |
# |    value_loss         | 0.00116        |
# ------------------------------------------
# day: 379, episode: 20
# begin_total_asset: 1000.00
# end_total_asset: 1600.05
# total_reward: 600.05
# total_cost: 365.18
# total_trades: 1219
# Sharpe: 0.695
# =================================
# ----------------------------------------
# | time/                 |              |
# |    fps                | 363          |
# |    iterations         | 200          |
# |    time_elapsed       | 27           |
# |    total_timesteps    | 10000        |
# | train/                |              |
# |    entropy_loss       | -11.9        |
# |    explained_variance | -0.72        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 199          |
# |    policy_loss        | 0.327        |
# |    reward             | 0.0037641162 |
# |    std                | 1.07         |
# |    value_loss         | 0.00119      |
# ----------------------------------------
# ======A2C Validation from:  2021-10-04 to  2022-01-03
# A2C Sharpe Ratio:  0.0
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.0005, 'batch_size': 400}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_315_1
# day: 379, episode: 30
# begin_total_asset: 1000.00
# end_total_asset: 7794.86
# total_reward: 6794.86
# total_cost: 1320.45
# total_trades: 1916
# Sharpe: 1.449
# =================================
# -------------------------------------
# | time/              |              |
# |    fps             | 448          |
# |    iterations      | 1            |
# |    time_elapsed    | 4            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.015350714 |
# -------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 413          |
# |    iterations           | 2            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0087886145 |
# |    clip_fraction        | 0.0869       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11.3        |
# |    explained_variance   | -1.19        |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.0457      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0131      |
# |    reward               | 0.014232607  |
# |    std                  | 0.997        |
# |    value_loss           | 0.104        |
# ------------------------------------------
# day: 379, episode: 40
# begin_total_asset: 1000.00
# end_total_asset: 1429.52
# total_reward: 429.52
# total_cost: 507.52
# total_trades: 1882
# Sharpe: 0.774
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 374          |
# |    iterations           | 3            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.008873125  |
# |    clip_fraction        | 0.125        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11.3        |
# |    explained_variance   | 0.0184       |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.0808      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0139      |
# |    reward               | -0.002598395 |
# |    std                  | 1            |
# |    value_loss           | 0.0965       |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 385           |
# |    iterations           | 4             |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.008943147   |
# |    clip_fraction        | 0.0991        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0.067         |
# |    learning_rate        | 0.0005        |
# |    loss                 | -0.0951       |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.00882      |
# |    reward               | -0.0034555537 |
# |    std                  | 1             |
# |    value_loss           | 0.0214        |
# -------------------------------------------
# day: 379, episode: 50
# begin_total_asset: 1000.00
# end_total_asset: 2033.54
# total_reward: 1033.54
# total_cost: 554.12
# total_trades: 1886
# Sharpe: 1.251
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 385          |
# |    iterations           | 5            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.014378715  |
# |    clip_fraction        | 0.158        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11.4        |
# |    explained_variance   | 0.22         |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.129       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0111      |
# |    reward               | -0.008260597 |
# |    std                  | 1.01         |
# |    value_loss           | 0.0335       |
# ------------------------------------------
# ======PPO Validation from:  2021-10-04 to  2022-01-03
# PPO Sharpe Ratio:  0.0
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 400}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_315_1
# ------------------------------------
# | time/              |             |
# |    episodes        | 4           |
# |    fps             | 28          |
# |    time_elapsed    | 53          |
# |    total_timesteps | 1520        |
# | train/             |             |
# |    actor_loss      | 11.6        |
# |    critic_loss     | 0.255       |
# |    learning_rate   | 0.0005      |
# |    n_updates       | 1140        |
# |    reward          | 0.017344454 |
# ------------------------------------
# day: 379, episode: 60
# begin_total_asset: 1000.00
# end_total_asset: 3305.30
# total_reward: 2305.30
# total_cost: 1.00
# total_trades: 1895
# Sharpe: 1.228
# =================================
# ------------------------------------
# | time/              |             |
# |    episodes        | 8           |
# |    fps             | 24          |
# |    time_elapsed    | 124         |
# |    total_timesteps | 3040        |
# | train/             |             |
# |    actor_loss      | 10.6        |
# |    critic_loss     | 0.148       |
# |    learning_rate   | 0.0005      |
# |    n_updates       | 2660        |
# |    reward          | 0.017344454 |
# ------------------------------------
# ------------------------------------
# | time/              |             |
# |    episodes        | 12          |
# |    fps             | 23          |
# |    time_elapsed    | 195         |
# |    total_timesteps | 4560        |
# | train/             |             |
# |    actor_loss      | 9.75        |
# |    critic_loss     | 0.156       |
# |    learning_rate   | 0.0005      |
# |    n_updates       | 4180        |
# |    reward          | 0.017344454 |
# ------------------------------------
# day: 379, episode: 70
# begin_total_asset: 1000.00
# end_total_asset: 3305.30
# total_reward: 2305.30
# total_cost: 1.00
# total_trades: 1895
# Sharpe: 1.228
# =================================
# ------------------------------------
# | time/              |             |
# |    episodes        | 16          |
# |    fps             | 22          |
# |    time_elapsed    | 268         |
# |    total_timesteps | 6080        |
# | train/             |             |
# |    actor_loss      | 8.92        |
# |    critic_loss     | 0.0867      |
# |    learning_rate   | 0.0005      |
# |    n_updates       | 5700        |
# |    reward          | 0.017344454 |
# ------------------------------------
# ------------------------------------
# | time/              |             |
# |    episodes        | 20          |
# |    fps             | 22          |
# |    time_elapsed    | 339         |
# |    total_timesteps | 7600        |
# | train/             |             |
# |    actor_loss      | 8.16        |
# |    critic_loss     | 0.0549      |
# |    learning_rate   | 0.0005      |
# |    n_updates       | 7220        |
# |    reward          | 0.017344454 |
# ------------------------------------
# ------------------------------------
# | time/              |             |
# |    episodes        | 24          |
# |    fps             | 22          |
# |    time_elapsed    | 410         |
# |    total_timesteps | 9120        |
# | train/             |             |
# |    actor_loss      | 7.46        |
# |    critic_loss     | 0.0297      |
# |    learning_rate   | 0.0005      |
# |    n_updates       | 8740        |
# |    reward          | 0.017344454 |
# ------------------------------------
# day: 379, episode: 80
# begin_total_asset: 1000.00
# end_total_asset: 3305.30
# total_reward: 2305.30
# total_cost: 1.00
# total_trades: 1895
# Sharpe: 1.228
# =================================
# ======DDPG Validation from:  2021-10-04 to  2022-01-03
# ======Best Model Retraining from:  2020-04-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# Ensemble Strategy took:  35.2251539905866  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2021-01-04  2021-04-06        PPO        0.0        0.0         0.0
# 1  189  2021-04-06  2021-07-06        PPO        0.0        0.0         0.0
# 2  252  2021-07-06  2021-10-04        PPO        0.0        0.0         0.0
# 3  315  2021-10-04  2022-01-03        PPO        0.0        0.0         0.0

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  nan

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0         1000.0  2021-04-06           NaN  2021-04-06
# 1         1000.0  2021-04-07           0.0  2021-04-07
# 2         1000.0  2021-04-08           0.0  2021-04-08
# 3         1000.0  2021-04-09           0.0  2021-04-09
# 4         1000.0  2021-04-12           0.0  2021-04-12

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return          0.0
# Cumulative returns     0.0
# Annual volatility      0.0
# Sharpe ratio           NaN
# Calmar ratio           NaN
# Stability              0.0
# Max drawdown           0.0
# Omega ratio            NaN
# Sortino ratio          NaN
# Skew                   NaN
# Kurtosis               NaN
# Tail ratio             NaN
# Daily value at risk    0.0
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.037486
# Cumulative returns     0.037335
# Annual volatility      0.134331
# Sharpe ratio           0.342028
# Calmar ratio           0.331049
# Stability              0.066383
# Max drawdown          -0.113235
# Omega ratio            1.058031
# Sortino ratio          0.480831
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.970301
# Daily value at risk   -0.016742
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
              baseline_ticker = 'DIA', 
              baseline_start = df_account_value.loc[0,'date'],
              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-04-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-04-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.00</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.00</td>
#       <td>2021-04-06</td>
#       <td>2021-04-06</td>
#       <td>2021-04-06</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/matplotlib/axis.py in convert_units(self, x)
#    1505         try:
# -> 1506             ret = self.converter.convert(x, self.units, self)
#    1507         except Exception as e:
#
# /usr/local/lib/python3.8/dist-packages/pandas/plotting/_matplotlib/converter.py in convert(values, unit, axis)
#     277         else:
# --> 278             values = DatetimeConverter._convert_1d(values, unit, axis)
#     279         return values
#
# /usr/local/lib/python3.8/dist-packages/pandas/plotting/_matplotlib/converter.py in _convert_1d(values, unit, axis)
#     312
# --> 313             values = dates.date2num(values)
#     314
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/dates.py in date2num(d)
#     445             d = np.asarray(d)
# --> 446         d = d.astype('datetime64[us]')
#     447
#
# ValueError: cannot convert float NaN to integer
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# <ipython-input-128-2c2678012bd0> in <module>
#       4 # Dow Jones Index: ^DJI
#       5 # NASDAQ 100: ^NDX
# ----> 6 backtest_plot(df_account_value,
#       7               baseline_ticker = 'DIA',
#       8               baseline_start = df_account_value.loc[0,'date'],
#
# /usr/local/lib/python3.8/dist-packages/finrl/plot.py in backtest_plot(account_value, baseline_start, baseline_end, baseline_ticker, value_col_name)
#      65
#      66     with pyfolio.plotting.plotting_context(font_scale=1.1):
# ---> 67         pyfolio.create_full_tear_sheet(
#      68             returns=test_returns, benchmark_rets=baseline_returns, set_context=False
#      69         )
#
# /usr/local/lib/python3.8/dist-packages/pyfolio/tears.py in create_full_tear_sheet(returns, positions, transactions, market_data, benchmark_rets, slippage, live_start_date, sector_mappings, round_trips, estimate_intraday, hide_positions, cone_std, bootstrap, unadjusted_returns, turnover_denom, set_context, factor_returns, factor_loadings, pos_in_dollars, header_rows, factor_partitions)
#     178                                      positions, transactions)
#     179
# --> 180     create_returns_tear_sheet(
#     181         returns,
#     182         positions=positions,
#
# /usr/local/lib/python3.8/dist-packages/pyfolio/plotting.py in call_w_context(*args, **kwargs)
#      52                 return func(*args, **kwargs)
#      53         else:
# ---> 54             return func(*args, **kwargs)
#      55     return call_w_context
#      56
#
# /usr/local/lib/python3.8/dist-packages/pyfolio/tears.py in create_returns_tear_sheet(returns, positions, transactions, live_start_date, cone_std, benchmark_rets, bootstrap, turnover_denom, header_rows, return_fig)
#     567
#     568     # Drawdowns
# --> 569     plotting.plot_drawdown_periods(
#     570         returns, top=5, ax=ax_drawdown)
#     571
#
# /usr/local/lib/python3.8/dist-packages/pyfolio/plotting.py in plot_drawdown_periods(returns, top, ax, **kwargs)
#     440         if pd.isnull(recovery):
#     441             recovery = returns.index[-1]
# --> 442         ax.fill_between((peak, recovery),
#     443                         lim[0],
#     444                         lim[1],
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1412     def inner(ax, *args, data=None, **kwargs):
#    1413         if data is None:
# -> 1414             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1415
#    1416         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_axes.py in fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5249     def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5250                      step=None, **kwargs):
# -> 5251         return self._fill_between_x_or_y(
#    5252             "x", x, y1, y2,
#    5253             where=where, interpolate=interpolate, step=step, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_axes.py in _fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5155         # Handle united data, such as dates
#    5156         ind, dep1, dep2 = map(
# -> 5157             ma.masked_invalid, self._process_unit_info(
#    5158                 [(ind_dir, ind), (dep_dir, dep1), (dep_dir, dep2)], kwargs))
#    5159
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_base.py in _process_unit_info(self, datasets, kwargs, convert)
#    2542                     if dataset_axis_name == axis_name and data is not None:
#    2543                         axis.update_units(data)
# -> 2544         return [axis_map[axis_name].convert_units(data)
#    2545                 if convert and data is not None else data
#    2546                 for axis_name, data in datasets]
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_base.py in <listcomp>(.0)
#    2542                     if dataset_axis_name == axis_name and data is not None:
#    2543                         axis.update_units(data)
# -> 2544         return [axis_map[axis_name].convert_units(data)
#    2545                 if convert and data is not None else data
#    2546                 for axis_name, data in datasets]
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axis.py in convert_units(self, x)
#    1506             ret = self.converter.convert(x, self.units, self)
#    1507         except Exception as e:
# -> 1508             raise munits.ConversionError('Failed to convert value(s) to axis '
#    1509                                          f'units: {x!r}') from e
#    1510         return ret
#
# ConversionError: Failed to convert value(s) to axis units: (NaT, Timestamp('2022-04-01 00:00:00+0000', tz='UTC'))
